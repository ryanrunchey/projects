# %%
import pandas as pd

filename = 'NEM_CurrentlyInterconnectedDataset_2017-11-30.csv'

df_cadgstats = pd.read_csv(filename)

df_cadgstats.head(10)
# Out:
# /Users/ryanrunchey/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (10,11,12,13,18,25,26,27,28,29,30,32,33,34,37,38,42,43,45,46,48,49,51,52,54,55,57,58,60,61,63,64,66,67,69,70,75,76,78,79,81,82,84,85,87,88,90,91,93,94,96,97,99,100,102,103,105,106,108,109,111,112) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Application Id Matched CSI Application Number Application Status Utility  \
# 0      PGE-INT-10                            NaN     Interconnected     PGE
# 1     PGE-INT-100                            NaN     Interconnected     PGE
# 2    PGE-INT-1000                            NaN     Interconnected     PGE
# 3   PGE-INT-10000                            NaN     Interconnected     PGE
# 4  PGE-INT-100002                  PGE-CSI-56484     Interconnected     PGE
# ...

# %%
import pandas as pd

filename = 'NEM_InterconnectionApplicationsDataset_2017-11-30.csv'

df_app = pd.read_csv(filename)

df_cadgstats.head(10)
# Out:
# /Users/ryanrunchey/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (1,2,12,13,14,15,20,21,28,29,30,31,32,35,36,37,44,45,47,48,50,51,53,54,56,57,59,60,62,63,65,66,68,69,71,72,77,78,80,81,83,84,86,87,89,90,92,93,95,96,98,99) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Application Id Matched CSI Application Number Application Status Utility  \
# 0      PGE-INT-10                            NaN     Interconnected     PGE
# 1     PGE-INT-100                            NaN     Interconnected     PGE
# 2    PGE-INT-1000                            NaN     Interconnected     PGE
# 3   PGE-INT-10000                            NaN     Interconnected     PGE
# 4  PGE-INT-100002                  PGE-CSI-56484     Interconnected     PGE
# 5  PGE-INT-100004                  PGE-CSI-56615     Interconnected     PGE
# ...
