# %% [markdown]
# # Import Libraries

# %%
import pandas as pd

# %% [markdown]
# # Google Project Sunroof

# %%
filepath = "google_projectsunroof/solar_potential_by_postal_code.csv"

df_solar = pd.read_csv(filepath)
df_solar.head(3)
# Out:
#    region_name state_name    lat_max    lat_min    lng_max    lng_min  \
# 0      50648.0       Iowa  42.482522  42.442844 -92.052619 -92.219113
# 1      52498.0       Iowa  42.033927  42.028445 -91.631963 -91.636456
# 2      50647.0       Iowa  42.653379  42.614552 -92.450545 -92.509698
#
#      lat_avg    lng_avg  yearly_sunlight_kwh_kw_threshold_avg  \
# 0  42.470563 -92.071952                                 980.9
# 1  42.031537 -91.633122                                1009.8
# 2  42.644734 -92.463196                                 980.9
#
#    count_qualified           ...             yearly_sunlight_kwh_n  \
# 0                1           ...                          0.000000
# 1               58           ...                      55101.258716
# 2                5           ...                          0.000000
#
#    yearly_sunlight_kwh_s  yearly_sunlight_kwh_e  yearly_sunlight_kwh_w  \
# 0            1864.582703            1012.349377               0.000000
# ...

# %%
df_solar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10621 entries, 0 to 10620
# Data columns (total 31 columns):
# region_name                             10620 non-null float64
# state_name                              10620 non-null object
# lat_max                                 10621 non-null float64
# lat_min                                 10621 non-null float64
# lng_max                                 10621 non-null float64
# lng_min                                 10621 non-null float64
# lat_avg                                 10621 non-null float64
# lng_avg                                 10621 non-null float64
# yearly_sunlight_kwh_kw_threshold_avg    10621 non-null float64
# count_qualified                         10621 non-null int64
# percent_covered                         10621 non-null float64
# percent_qualified                       10621 non-null float64
# number_of_panels_n                      10621 non-null int64
# ...

# %%
df_solar = df_solar.dropna()
df_solar.shape
# Out:
# (10585, 31)

# %%
# cast region_name astype int because this is Zip Code
# set_index to region_name

df_solar['region_name'] = df_solar['region_name'].astype(int, copy=False)
df_solar['region_name'] = df_solar['region_name'].astype(str, copy=False)
df_solar = df_solar.set_index('region_name')
df_solar.head(2)
# Out:
#             state_name    lat_max    lat_min    lng_max    lng_min    lat_avg  \
# region_name
# 50648             Iowa  42.482522  42.442844 -92.052619 -92.219113  42.470563
# 52498             Iowa  42.033927  42.028445 -91.631963 -91.636456  42.031537
#
#                lng_avg  yearly_sunlight_kwh_kw_threshold_avg  count_qualified  \
# region_name
# 50648       -92.071952                                 980.9                1
# 52498       -91.633122                                1009.8               58
#
#              percent_covered           ...             yearly_sunlight_kwh_n  \
# region_name                            ...
# 50648               0.658979           ...                          0.000000
# 52498              95.588235           ...                      55101.258716
#
#              yearly_sunlight_kwh_s  yearly_sunlight_kwh_e  \
# region_name
# 50648                  1864.582703            1012.349377
# ...

# %%
# select state_name == California

df_solar_ca = df_solar[df_solar['state_name'] == 'California']
df_solar_ca.shape
# Out:
# (1177, 30)

# %%
# drop extraneous columns

col_drop = ['state_name','lat_max', 'lat_min', 'lng_max', 'lng_min', 'install_size_kw_buckets',\
            'carbon_offset_metric_tons', 'existing_installs_count']

df_solar_ca = df_solar_ca.drop(col_drop, axis=1)
df_solar_ca.shape
# Out:
# (1177, 22)

# %%
# pickle DataFrame

df_solar_ca.to_pickle('03_df_solar_ca.pkl')
